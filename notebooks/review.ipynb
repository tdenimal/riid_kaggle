# %%
import json
import matplotlib.pyplot as plt
import lightgbm as lgb

# %%
with open('auc_mean_1.json', 'r') as f:
     model_cv_mean = json.loads(f.read())

plt.title("auc mean")
plt.plot(model_cv_mean)
plt.show()

# %%
model_cv_mean[len(model_cv_mean)-1]
# Out:
# 0.7668540453158867

# %%
with open('auc_stdv_1.json', 'r') as f:
     model_cv_stdv = json.loads(f.read())

plt.title("auc stdv")
plt.plot(model_cv_stdv)
plt.show()

# %%
lgb.plot_importance(lgb.Booster(model_file="model_1.bin"))
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>
